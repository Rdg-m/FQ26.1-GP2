# %%
import sys
import os
from load import load_data
df_ibov = load_data(
    indice='^BVSP', 
    fonte='yfinance', 
    tempo='10y', 
    salvar=True
)
display(df_ibov.head(10))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Open     High      Low    Close   Volume
# Ticker        ^BVSP    ^BVSP    ^BVSP    ^BVSP    ^BVSP
# Date
# 2016-04-06  49054.0  49054.0  47874.0  48096.0  3810000
# 2016-04-07  48099.0  48940.0  48099.0  48513.0  3059900
# 2016-04-08  48517.0  50486.0  48517.0  50293.0  5047700
# 2016-04-11  50303.0  51089.0  50078.0  50165.0  4050700
# 2016-04-12  50166.0  52327.0  50166.0  52002.0  5146900
# 2016-04-13  52010.0  53844.0  52010.0  53150.0  6376500
# 2016-04-14  53150.0  53699.0  52242.0  52411.0  5492100
# 2016-04-15  52414.0  53390.0  52414.0  53228.0  5047800
# 2016-04-18  53229.0  53479.0  52305.0  52894.0  4385600
# 2016-04-19  52894.0  54054.0  52894.0  53710.0  5033900
