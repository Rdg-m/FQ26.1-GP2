# %%
import sys
import os
from load import load_data
df_ibov = load_data(
    indice='^BVSP', 
    fonte='yfinance', 
    tempo='10y', 
    salvar=True
)
display(df_ibov.head(10))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Open     High      Low    Close   Volume
# Ticker        ^BVSP    ^BVSP    ^BVSP    ^BVSP    ^BVSP
# Date
# 2016-04-25  52911.0  52949.0  51748.0  51862.0  3693200
# 2016-04-26  51867.0  53108.0  51838.0  53083.0  3749400
# 2016-04-27  53094.0  54560.0  53094.0  54478.0  4897900
# 2016-04-28  54475.0  54978.0  53963.0  54312.0  4413500
# 2016-04-29  54317.0  54705.0  53592.0  53911.0  4898400
# 2016-05-02  53910.0  54113.0  53265.0  53562.0  3286100
# 2016-05-03  53557.0  53557.0  52260.0  52260.0  3892400
# 2016-05-04  52253.0  52672.0  51931.0  52553.0  4263800
# 2016-05-05  52569.0  53071.0  51311.0  51671.0  3653100
# 2016-05-06  51671.0  52159.0  51204.0  51718.0  3296100
